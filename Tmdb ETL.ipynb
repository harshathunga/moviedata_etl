# %%
import requests

url = "https://api.themoviedb.org/3/trending/all/week?language=en-US&page=" i

headers = {
    "accept": "application/json",
    "Authorization": ""
}

response = requests.get(url, headers=headers)
r = response.json()
r

# %%
# i = 1
# url = "https://api.themoviedb.org/3/trending/all/week?language=en-US&page=" + str(i)


o = []

for i in range(1,5):
    url = "https://api.themoviedb.org/3/trending/all/week?language=en-US&page=" + str(i)
    headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiNTk4ZDQwOTBmZGE4ZGU2ZTgzYjU2OTk5NTBhZmQ3ZCIsIm5iZiI6MTY1MzQ2MzU3Mi4zNjksInN1YiI6IjYyOGRkYTE0NmYzMWFmMTM5MjQ1OTUzMiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.PC6Fg1CuAP6FCc38GDd20TdFTM1V57Ecz1edOGkTb4s"
}
    response = requests.get(url, headers=headers)
    r = response.json()
    o.append(r)

# %%
o[3]
# Out:
# {'page': 4,
#  'results': [{'backdrop_path': '/ey6HaUwo4CJoOYDlJ0M90ykJ0dt.jpg',
#    'id': 1401905,
#    'title': "Don't Die: The Man Who Wants to Live Forever",
#    'original_title': "Don't Die: The Man Who Wants to Live Forever",
#    'overview': 'In this documentary, wealthy entrepreneur Bryan Johnson puts his body and fortune on the line to defy aging and extend his life beyond all known limits.',
#    'poster_path': '/7VqUPN0oRHfYV9hdZcal1ZzffmV.jpg',
#    'media_type': 'movie',
#    'adult': False,
#    'original_language': 'en',
#    'genre_ids': [99],
#    'popularity': 109.546,
#    'release_date': '2025-01-01',
#    'video': False,
#    'vote_average': 5.8,
#    'vote_count': 9},
#   {'backdrop_path': '/enVrO8TRkdT8dmYXTfI4sEjR5Kp.jpg',
#    'id': 222766,
#    'name': 'The Day of the Jackal',
#    'original_name': 'The Day of the Jackal',
# ...

# %%
# print(len(no))
title =[]
popularity=[]
media = []
relese_d =[]
ol =[]
for i in range(0,4):
   for j in range(0,20):

       mt = no[i][j]['media_type']
       populty = no[i][j]['popularity']
       popularity.append(populty)
       orl = no[i][j]['original_language']
       ol.append(orl)
       
       media.append(mt)
       if 'title' in no[i][j]:
           t = (no[i][j]['title'])
           title.append(t)
           rd = (no[i][j]['release_date'])
           relese_d.append(rd)
           
       else:
           et = (no[i][j]['name'])
           title.append(et)
           rdd = (no[i][j]['first_air_date'])
           relese_d.append(rdd)

# %%
o[0]['results'][19]['popularity']
# Out:
# 2540.729

# %%
import pandas as pd

# %%
df = pd.DataFrame({'title': title, 'media_type': media, 'popularity': popularity, 'release_date': relese_d, 'original_language':ol, })

# %%
df
# Out:
#                                     title media_type  popularity release_date  \
# 0                                  Wicked      movie    2943.848   2024-11-20
# 1                              Squid Game         tv   13121.205   2021-09-17
# 2                                  ZENSHU         tv      51.338   2025-01-05
# 3   Wallace & Gromit: Vengeance Most Fowl      movie     273.489   2024-12-18
# 4                            Gladiator II      movie    4782.551   2024-11-05
# ..                                    ...        ...         ...          ...
# 75                                  Venom      movie     213.888   2018-09-28
# 76                Guardians of the Dafeng         tv     475.241   2024-12-28
# 77                      Blade Runner 2049      movie     111.939   2017-10-04
# 78                   Sonic the Hedgehog 2      movie     582.740   2022-03-30
# 79                              Outlander         tv     447.861   2014-08-09
#
#    original_language
# ...

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",           
    user="root",       # give your sql userid
    password="",   # give your sql password
    database="tmdb"    #your database name 
)

# %%
cursor = conn.cursor()

# %%
for index, i in df.iterrows():
    sql = "insert into tmd(title,media_type,popularity,release_date,original_language) values(%s,%s,%s,%s,%s)"
    val = (i['title'],	i['media_type'],i['popularity'],i['release_date'],i['original_language'])
    cursor.execute(sql, val)
conn.commit()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              80 non-null     object
#  1   media_type         80 non-null     object
#  2   popularity         80 non-null     float64
#  3   release_date       80 non-null     object
#  4   original_language  80 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 3.3+ KB
